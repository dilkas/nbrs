# %%
atomic ctrl S0 = 0;
atomic ctrl S1 = 0;
atomic ctrl S2 = 0;

big initial = S0;
big heads = S2;
# Out:
# initial
# heads

# %%
action a
  react toTemp = S0 -[1.]-> S1;
end
# Out:
# toTemp
# <table>
#     <tr>
#         <td><img src="jupyter-images/2/toTemp_lhs.svg"></td>
#         <td style="padding-left: 25px; padding-right: 25px;">
#             <h1>&rarr;</h1>
#         </td>
#         <td><img src="jupyter-images/2/toTemp_rhs.svg"></td>
#     </tr>
# </table>
